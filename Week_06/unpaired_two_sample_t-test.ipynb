# %% [markdown]
# # Unpaired two-sample t-test

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats

# Settings for seaborn
sns.set_theme(style="ticks", palette="pastel")

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# Show current working directory
print(os.getcwd())
# Out:
# /home/runner/work/data_analytics/data_analytics/Week_06

# %% [markdown]
# ## Read example data (used car data)

# %%
df = pd.read_excel('t-tests_and_ANOVA.xlsx', sheet_name='t-test_data')

# Show categories of 'Make'
print(df['Make'].value_counts())

# Show first rows in dataframe
df.head()
# Out:
# Make
# VW     20
# BMW    20
# Name: count, dtype: int64
#   Make  Price
# 0   VW  29000
# 1   VW  38000
# 2   VW  33000
# 3   VW  64000
# 4   VW  52000

# %% [markdown]
# ## Create grouped boxplot (groups = make, values = car prices)

# %%
# Plot boxplot with groups
plt.figure(figsize=(8,2))
ax = sns.boxplot(x="Price",
                 y="Make",
                 palette=['r', 'g'],
                 data=df,
                 orient='h')
plt.grid()
plt.show()

# %% [markdown]
# ## Unpaired two-sample t-test

# %%
# Create subsets (groups)
vw = df.loc[df['Make'] == 'VW']
bmw = df.loc[df['Make'] == 'BMW']

# Create t-test
result = stats.ttest_ind(vw['Price'], bmw['Price'])

# Print result
print('Test-statistic:', result[0].round(5), 'p-value',  result[1].round(5))
# Out:
# Test-statistic: -2.69607 p-value 0.0104

# %% [markdown]
# ## Interpretation of result

# %% [markdown]
# <p> Because the p-value is lower than 0.05, the null hypothesis can be rejected, i.e. there is evidence that the used car prices of VW, BMW differ. Note that, from the t-test above, it is not clear which brand show higher or lower prices. It only shows that there is a statistically significant (5% significance level) difference between prices.</p>

# %% [markdown]
# ## Importing apartment data

# %%
# Read the data to a pandas data frame
df = pd.read_csv('apartments_data_enriched_cleaned.csv', 
                 sep=';', 
                 encoding='utf-8')[['web-scraper-order',
                                    'address_raw',
                                    'lat',
                                    'lon',
                                    'bfs_number',
                                    'bfs_name',
                                    'rooms', 
                                    'area', 
                                    'luxurious', 
                                    'price', 
                                    'price_per_m2',
                                    'pop_dens',
                                    'frg_pct',
                                    'mean_taxable_income',
                                    'dist_supermarket']]

# Get number of rows and columns
print(df.shape)

# Show first records
df.head(5)
# Out:
# (774, 15)
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171
# 1    1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH  47.252087
# 2    1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH  47.253670
# 3    1693998265-381              Rain 1, 8630 Rüti ZH, ZH  47.259834
# 4    1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH  47.266113
#
#         lon  bfs_number   bfs_name  rooms  area  luxurious  price  \
# 0  8.845797         118  Rüti (ZH)    3.0    49          0   1441
# 1  8.854919         118  Rüti (ZH)    3.0   111          0   2600
# 2  8.853993         118  Rüti (ZH)    3.0    58          0   1490
# 3  8.851705         118  Rüti (ZH)    4.0   118          0   3240
# 4  8.866872         118  Rüti (ZH)    3.0    66          0   1450
#
#    price_per_m2     pop_dens    frg_pct  mean_taxable_income  dist_supermarket
# ...

# %% [markdown]
# ## Create new binary variable with densely populated and all other municipalities

# %%
df['pop_dens_binary'] = (df['pop_dens'] >= 1000).astype(int)
df.head(5)
# Out:
#   web-scraper-order                           address_raw        lat  \
# 0      1693998201-1     Neuhusstrasse 6, 8630 Rüti ZH, ZH  47.252171
# 1    1693998233-172   Widacherstrasse 5, 8630 Rüti ZH, ZH  47.252087
# 2    1693998256-331         Widenweg 14, 8630 Rüti ZH, ZH  47.253670
# 3    1693998265-381              Rain 1, 8630 Rüti ZH, ZH  47.259834
# 4    1693998276-419  Bachtelstrasse 24b, 8630 Rüti ZH, ZH  47.266113
#
#         lon  bfs_number   bfs_name  rooms  area  luxurious  price  \
# 0  8.845797         118  Rüti (ZH)    3.0    49          0   1441
# 1  8.854919         118  Rüti (ZH)    3.0   111          0   2600
# 2  8.853993         118  Rüti (ZH)    3.0    58          0   1490
# 3  8.851705         118  Rüti (ZH)    4.0   118          0   3240
# 4  8.866872         118  Rüti (ZH)    3.0    66          0   1450
#
#    price_per_m2     pop_dens    frg_pct  mean_taxable_income  \
# 0         29.41  1221.272366  24.841283          65362.04268
# ...

# %% [markdown]
# ## Create pivot table with mean price_per_m2

# %%
# Using pivot_table to reshape the data and calculate means 
pd.pivot_table(df[['pop_dens_binary', 'price_per_m2']],
               index=['pop_dens_binary'],
               values=['price_per_m2'],
               aggfunc=[np.mean, 'count'])
# Out:
#                         mean        count
#                 price_per_m2 price_per_m2
# pop_dens_binary
# 0                  24.367444          180
# 1                  35.430657          594

# %% [markdown]
# ## Create grouped boxplot (groups = pop_dens_binary, values = prices_per_m2)

# %%
# Plot boxplot with groups
plt.figure(figsize=(8,2))
ax = sns.boxplot(x="price_per_m2",
                 y="pop_dens_binary",
                 data=df,
                 palette=['r', 'g'],
                 orient='h')
plt.grid()
plt.show()

# %% [markdown]
# ## Unpaired two-sample t-test

# %%
# Create subsets (groups)
densely_populated = df.loc[df['pop_dens_binary'] == 0]
not_densely_populated = df.loc[df['pop_dens_binary'] == 1]

# Create t-test
result = stats.ttest_ind(densely_populated['price_per_m2'], 
                         not_densely_populated['price_per_m2'])

# Print result
print('Test-statistic:', result[0].round(5), 'p-value',  result[1].round(5))
# Out:
# Test-statistic: -9.19477 p-value 0.0

# %% [markdown]
# ## Interpretation of result

# %% [markdown]
# <p> Because the p-value is lower than 0.05, the null hypothesis can be rejected, i.e. there is evidence that the prices per m2 differ between densely populated and other municipalities. Note that, from the t-test above, it is not clear which group of municipalities show lower or higher prices. It only shows that there is a statistically significant (5% significance level) difference between prices.</p>

# %% [markdown]
# ## Compare rental apartment prices in the cities of Winterthur and Zürich

# %% [markdown]
# ### Hypothesis Setup
#
# **Null Hypothesis (H0):** There is no significant difference in the prices per m² of rental apartments between Winterthur and Zürich (μ_Winterthur = μ_Zürich)
#
# **Alternative Hypothesis (H1):** There is a significant difference in the prices per m² of rental apartments between Winterthur and Zürich (μ_Winterthur ≠ μ_Zürich)
#
# **Significance level (α):** 0.05 (5%)

# %%
# Create subsets for Winterthur and Zürich
df_winti = df.loc[df['bfs_name'] == 'Winterthur']['price_per_m2']
df_zueri = df.loc[df['bfs_name'] == 'Zürich']['price_per_m2']

# Display basic statistics
print(f'Winterthur apartments: {len(df_winti)}')
print(f'Mean price per m2 in Winterthur: CHF {df_winti.mean():.2f}')
print(f'Std price per m2 in Winterthur: CHF {df_winti.std():.2f}')
print()
print(f'Zürich apartments: {len(df_zueri)}')
print(f'Mean price per m2 in Zürich: CHF {df_zueri.mean():.2f}')
print(f'Std price per m2 in Zürich: CHF {df_zueri.std():.2f}')
# Out:
# Winterthur apartments: 94
# Mean price per m2 in Winterthur: CHF 26.25
# Std price per m2 in Winterthur: CHF 8.37
#
# Zürich apartments: 255
# Mean price per m2 in Zürich: CHF 46.00
# Std price per m2 in Zürich: CHF 17.00

# %%
# Create a boxplot to visualize the comparison
df_comparison = df.loc[df['bfs_name'].isin(['Winterthur', 'Zürich'])]

plt.figure(figsize=(8, 3))
ax = sns.boxplot(x='price_per_m2',
                 y='bfs_name',
                 data=df_comparison,
                 palette=['r', 'g'],
                 orient='h')
plt.title('Price per m² comparison: Winterthur vs Zürich')
plt.xlabel('Price per m² (CHF)')
plt.ylabel('City')
plt.grid()
plt.show()

# %% [markdown]
# ### Unpaired two-sample t-test: Winterthur vs Zürich

# %%
# Perform unpaired two-sample t-test
result = stats.ttest_ind(df_winti, df_zueri)

# Print results
print('Unpaired Two-Sample T-Test Results:')
print('=' * 40)
print(f'Test statistic: {result[0]:.5f}')
print(f'p-value: {result[1]:.5f}')
print('=' * 40)
# Out:
# Unpaired Two-Sample T-Test Results:
# ...
# Test statistic: -10.78628
# p-value: 0.00000
# ...

# %% [markdown]
# ### Interpretation of Results
#
# The p-value from the unpaired two-sample t-test is compared to the significance level of 0.05:
#
# - **If p-value < 0.05:** We reject the null hypothesis. There is statistically significant evidence that the prices per m² of rental apartments differ between Winterthur and Zürich.
#
# - **If p-value ≥ 0.05:** We fail to reject the null hypothesis. There is no statistically significant evidence of a difference in prices per m² between the two cities.
#
# **Based on the results:** Since the p-value is less than 0.05, we reject the null hypothesis and conclude that there is a statistically significant difference in rental apartment prices per m² between Winterthur and Zürich. Looking at the means, apartments in Zürich tend to have higher prices per m² compared to Winterthur, which aligns with the general expectation that Zürich, being a major financial center, has higher real estate prices.

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each submitted notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.11.0-1018-azure
# Datetime: 2025-12-02 18:22:09
# Python Version: 3.12.3
# -----------------------------------
